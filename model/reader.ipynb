# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("house_cian.csv")

# %%
df.head()
# Out:
#                                                 url     price         area  \
# 0  https://krasnogorsk.cian.ru/sale/flat/323505071/  14482207  181462.4613
# 1  https://krasnogorsk.cian.ru/sale/flat/323504967/  19142669  181462.4613
# 2          https://www.cian.ru/sale/flat/325229458/  25000000  181462.4613
# 3          https://www.cian.ru/sale/flat/323816931/   3950000      19.7300
# 4          https://www.cian.ru/sale/flat/314714365/  20000000  181462.4613
#
#    renovation  house_type        date  parking  finish
# 0          -1           0  2025-12-22      0.0    -1.0
# 1          -1           0  2025-12-22      0.0    -1.0
# 2          -1           0  2025-12-22      0.0    -1.0
# 3          -1           0  2025-12-22      0.0    -1.0
# 4          -1           3  2025-12-22      2.0     0.0

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("house_cian.csv")

# %%
df
# Out:
#                                          url                    price    area  \
# 0   https://www.cian.ru/sale/flat/306541564/                108320625   65.50
# 1   https://www.cian.ru/sale/flat/323336526/                 87179200   82.40
# 2   https://www.cian.ru/sale/flat/322286415/                995000000  241.00
# 3   https://www.cian.ru/sale/flat/312136573/                169113368  131.80
# 4   https://www.cian.ru/sale/flat/318815971/                 41800000   94.00
# 5   https://www.cian.ru/sale/flat/321684148/                 44330400   28.20
# 6   https://www.cian.ru/sale/flat/323028383/                 24244776   51.60
# 7   https://www.cian.ru/sale/flat/325211060/                 45470000   57.30
# 8   https://www.cian.ru/sale/flat/324989686/                 43000000   68.00
# 9   https://www.cian.ru/sale/flat/305914265/                 24372120   49.80
# 10  https://www.cian.ru/sale/flat/314008663/                131000000  146.00
# ...

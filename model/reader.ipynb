# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("house_cian.csv")

# %%
df
# Out:
#                                                  url     price    area  \
# 0           https://www.cian.ru/sale/flat/325239361/  22078665   51.00
# 1           https://www.cian.ru/sale/flat/325229458/  25000000   62.70
# 2           https://www.cian.ru/sale/flat/323816931/   3950000   19.73
# 3           https://www.cian.ru/sale/flat/325112894/  20625480   42.30
# 4           https://www.cian.ru/sale/flat/325062248/  65000000  123.00
# 5           https://www.cian.ru/sale/flat/324873119/  28500000   72.10
# 6           https://www.cian.ru/sale/flat/325240838/  20000160   43.00
# 7           https://www.cian.ru/sale/flat/322846238/  11990000   47.00
# 8           https://www.cian.ru/sale/flat/315362487/  10500000   32.40
# 9           https://www.cian.ru/sale/flat/325112904/  15284880   28.40
# 10  https://krasnogorsk.cian.ru/sale/flat/323263871/  12500000   55.28
# 11          https://www.cian.ru/sale/flat/323415442/  37500000   84.10
# ...
